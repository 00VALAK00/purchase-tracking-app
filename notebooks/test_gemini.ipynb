# %%
gemini_api_key = "AIzaSyDZ-_Qdrmj1G9JdtrAQF4bAv1tJbMEM0P8"

# %%
from PIL import Image
from google.genai import types
import io

receipt_path = "images/receipt-template.png"

# with open(receipt_path, 'b') as f:
#       image_bytes = f.read()

# image = types.Part.from_bytes(
#   data=image_bytes, mime_type="image/jpeg"
# )
with open(receipt_path, "rb") as f:
    image_bytes = f.read()
image = Image.open(io.BytesIO(image_bytes),"r")

# %%
from typing import List
import google.genai as genai
from pydantic import BaseModel, Field


client = genai.Client(api_key=gemini_api_key)

class Item(BaseModel):
    items: str
    price: float

class ReceiptData(BaseModel):
    items: List[Item] = Field(default_factory=list, description="a list of items in the receipt and their corresponding prices")



response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=["extract the relevant information from this receipt", image],
        config={
            "response_mime_type": "application/json",
            "response_schema": ReceiptData,
        },
    )
    # Parse and return the structured result
print(response.text)
# Out:
# {
#   "items": [
#     {
#       "items": "Front and rear brake cables",
#       "price": 100.00
#     },
#     {
#       "items": "New set of pedal arms",
#       "price": 30.00
#     },
#     {
#       "items": "Labor 3hrs",
#       "price": 15.00
#     }
#   ]
# }

# %%
print(response.text)
# Out:
# [
#   {
#     "items": [
#       {
#         "items": "Front and rear brake cables",
#         "price": 100.00
#       },
#       {
#         "items": "New set of pedal arms",
#         "price": 30.00
#       },
#       {
#         "items": "Labor 3hrs",
#         "price": 15.00
#       }
#     ]
#   }
# ]
